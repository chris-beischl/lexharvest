# %%
from lexharvest.normalizers.spacy_normalizer import SpaCyNormalizer

# %%
normalizer = SpaCyNormalizer("es", "es_core_news_sm")
print(normalizer("cuento", pos_hint="noun"))
print(normalizer("cuento", pos_hint="verb"))
